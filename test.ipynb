# %%
import torch
from ultralytics import YOLO

# Load the trained model
model = YOLO("BDD100K_YOLOv8/yolov8n_train/weights/best.pt")  # Update the path if needed

# Define input video and output path
input_video = r"C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4"  # Change this to the path of your video
output_video = "output.mp4"

# Run object detection on the video
results = model.predict(source=input_video, save=True, save_txt=True, conf=0.25)

print("Detection completed. Check the output folder for results.")
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 8 cars, 3 motorcycles, 55.3ms
# video 1/1 (frame 2/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 8 cars, 3 motorcycles, 22.4ms
# video 1/1 (frame 3/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 9 cars, 3 motorcycles, 19.4ms
# ...

# %%
"C:\Users\Mahesh\Downloads\videoplayback.webm"

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("BDD100K_YOLOv8/yolov8n_train/weights/best.pt")  # Update path if needed

# Define input video and output path
input_video = r"C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4"  # Change to your video path
output_video = "output_low_conf.mp4"

# Run object detection with a lower confidence threshold
results = model.predict(source=input_video, save=True, save_txt=True, conf=0.15)  # Lower confidence

print("Detection completed with a low confidence threshold. Check the output folder for results.")
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 14 cars, 5 motorcycles, 81.5ms
# video 1/1 (frame 2/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 14 cars, 5 motorcycles, 18.1ms
# video 1/1 (frame 3/3505) C:\Users\Mahesh\Downloads\youtube video #062nwslzyOQ.mp4: 384x640 13 cars, 6 motorcycles, 25.8ms
# ...
